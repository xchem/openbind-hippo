# %% [markdown]
# # OpenBind-HIPPO
#
# - **Target: A71EV2A**
# - **Cycle: 01**
#
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import hippo
import mrich
from mrich import print
from pathlib import Path
from os import environ
import shutil
import molparse as mp
import pandas as pd
import plotly.express as px
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Config

# %%
target_name = "XX01ZVNS2B"
target_dir = Path(environ["BULK"]) / "TARGETS" / target_name
cycle_name = "cycle_01"
cycle_dir = Path(cycle_name)
aligned_dir = target_dir / "aligned_files"

# %% [markdown]
# ## Animal

# %%
animal = hippo.HIPPO(target_name, target_dir / f"{target_name}.sqlite")
# Out:
#  Creating HIPPO animal
# name = XX01ZVNS2B
# db_path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/XX01ZVNS2B/XX01ZVNS2B.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/XX01ZVNS2B/XX01ZVNS2B.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/XX01ZVNS2B/XX01ZVNS2B.sqlite!
#  Success  Initialised animal HIPPO("XX01ZVNS2B")!

# %%
df = pd.read_excel("cycle_01/chem_review/openbind_xx01zvns2b_c1_scaffolds_1steps.xlsx")#, sheet_name="chem-review")
select = df[df["lisa-select"]=="Y"]
print(len(select))
ids = [int(cname[1:]) for cname in select["target-names"]]
cset = animal.compounds[ids]
cset.add_tag("openbind_xx01zvns2b_c1_scaffolds_chemok")
cset
# Out:
# 767
# Tagged {C × 767} w/ "openbind_xx01zvns2b_c1_scaffolds_chemok"
# {C × 767}

# %%
df = pd.read_excel("cycle_01/chem_review/openbind_xx01zvns2b_c1_scaffolds_2steps.xlsx")#, sheet_name="chem-review")
select = df[df["lisa-select"]=="Y"]
print(len(select))
ids = [int(cname[1:]) for cname in select["target-names"]]
cset = animal.compounds[ids]
cset.add_tag("openbind_xx01zvns2b_c1_scaffolds_chemok")
cset
# Out:
# 0
# Tagged {C × 0} w/ "openbind_xx01zvns2b_c1_scaffolds_chemok"
# {C × 0}

# %%
bbdb = hippo.HIPPO("BB", Path(environ["HOME2"])/"EnamineCatalogs/enamine_bb_hippo.sqlite")
# Out:
#  Creating HIPPO animal
# name = BB
# db_path = /opt/xchem-fragalysis-2/maxwin/EnamineCatalogs/enamine_bb_hippo.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = /opt/xchem-fragalysis-2/maxwin/EnamineCatalogs/enamine_bb_hippo.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ /opt/xchem-fragalysis-2/maxwin/EnamineCatalogs/enamine_bb_hippo.sqlite!
#  Success  Initialised animal HIPPO("BB")!

# %%
animal.quote_reactants(bbdb)
# Out:
# #compounds = 3618
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# Output()
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)OC!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NC(C)C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(N)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NN!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OCC(=O)O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])n1cc(Br)cn1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]c1ccc(Br)cc1!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])OS(C)(=O)=O!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]C([2H])([2H])NCC(F)(F)F!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1cccc(Br)c1!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
#  Warning  Isotope(s) in SMILES: [2H]c1c(Br)cnn1C!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# #new quotes = 30140
# #quoted_compounds = 1757
# #unquoted_compounds = 1861

# %% [markdown]
# ## Queue BulkDock (re)placements

# %%
scaffold_poses = animal.poses(tag="openbind_xx01zvns2b_c1_scaffolds_chemok_bbok")
elaborated_scaffolds = scaffold_poses.compounds.elabs.scaffolds
elaborated_scaffold_poses = animal.poses[set(elaborated_scaffolds.poses.ids).intersection(set(scaffold_poses.ids))]
elaborated_scaffold_poses
# Out:
# {P × 45}

# %%
data = []
for i,pose in enumerate(elaborated_scaffold_poses):
    print(i, pose)
    compound = pose.compound
    elabs = compound.elabs
    reference = pose.reference
    inspirations = pose.inspirations

    inspiration_d = dict()
    for i, name in enumerate(inspirations.names):
        inspiration_d[f"hit{i+1}"] = name
    
    for elab in mrich.track(elabs):
        d = dict(smiles=elab.smiles)
        d.update(inspiration_d)
        data.append(d)

df = pd.DataFrame(data)
df.to_csv("cycle_01/syndirella/elabs/xx01zvns2b_c1_elab_bulkdock_input.csv", index=False)
df
# Out:
# 0 C119->P17076: "DHEAQALHKCHLOS-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 1 C18613->P20591: "XFFIHLDPRDKNKR-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 2 C18682->P20632: "CIWIMLBMRDLEFZ-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 3 C193->P23307: "LFCFADNCZRJYKM-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 4 C27833->P24129: "AAOWTMGLVHBFNB-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 5 C35751->P27622: "KADSGMPYWRRADT-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 6 C39979->P29376: "YLQHTSFPYPSXSW-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 7 C5576->P31894: "BWQHUTSQNYTJCI-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 8 C51867->P36023: "ZTHZBLAVMPXHMP-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 9 C55811->P44733: "CYPOFIRFZWWIJF-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 10 C117748->P47327: "HQJVWWZLOLLFOC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 11 C4344->P48957: "IANSQNGDXZKZMC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 12 C4755->P49137: "FXWZJNDKYPKVCU-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 13 C9828->P50682: "NAPZUNQCBHIRPL-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 14 C61266->P54277: "NFFXHWPBOGQOAI-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 15 C64241->P55921: "NVVXDBBCPYCMRN-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 16 C64652->P56197: "ZFCFMSIKJGEQIG-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 17 C64791->P56257: "MFZOQTVMCFTJFC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 18 C64798->P56264: "PVWNPFUPWZVGMP-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 19 C65040->P56493: "RIZNQZOXTPMWOW-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 20 C60166->P57300: "FLKNWAFFRSIEQV-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 21 C66477->P57358: "FZPVTGVORHPRMV-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 22 C65268->P58291: "XJHFOHPLVXEAJK-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 23 C68073->P58306: "SKDJHYMDJKHBLX-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 24 C108373->P60858: "HONZPOPPNAQRJH-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 25 C108379->P60864: "KVVPNFQDRHKSIT-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 26 C108381->P60865: "FQPYZRHCGIEGGC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 27 C108383->P60867: "DPYOJOSEVBEMBW-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 28 C108385->P60869: "DQRUAVNAEHNBMF-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 29 C108396->P60878: "KGTBMRSXKDMOPW-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 30 C108399->P60881: "JKOJGNKTCVRBMD-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 31 C108403->P60885: "ODAARTYSKDMQEJ-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 32 C108410->P60891: "AUXIMAVBHFYSOM-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 33 C108828->P61241: "MDHIDMWPVSUSIH-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 34 C110510->P63966: "PPXTXQWZJYEIPC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 35 C112762->P64483: "ABCCHUVOZOZXSJ-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 36 C48749->P65060: "XYOFFROFSMOCNR-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 37 C118335->P65140: "ICULPCWAIXXDSL-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 38 C118342->P65141: "USLQWDDSHRJFIX-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 39 C65345->P65161: "DFYBXILNMWHGOO-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 40 C119032->P65868: "GUQBXRHGLOWICG-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 41 C119043->P65875: "KQKNLWKVNWUMHC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 42 C119143->P65947: "NNBHYCZETFFDQK-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 43 C61750->P66179: "MMOYNOVVZMWGSB-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# 44 C109063->P66377: "XKJVMBDEKZNDDC-UHFFFAOYSA-N"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
#                                                  smiles    hit1    hit2 hit3  \
# 0            O=C1NCc2cc(NC(=O)c3cc(F)cc4[nH]nnc34)ccc21  Z3093a  Z5348a  NaN
# 1     O=C(Nc1ccc2c(c1)CN(c1ccccc1)C2)c1cc(F)cc2[nH]n...  Z3093a  Z5348a  NaN
# 2     O=C1NC(=O)c2cc(NC(=O)C3CCN(C(=O)c4cc(F)cc5[nH]...  Z3093a  Z5348a  NaN
# 3     O=C(c1ccc2c(c1)C1(CCOCC1)C(=O)N2)N1Cc2ccc(NC(=...  Z3622a  Z3677a  NaN
# 4     CN1Cc2ccc(NC(=O)c3ccc4c(c3)C3(CCOCC3)C(=O)N4)c...  Z3677a  Z4590a  NaN
# ...                                                 ...     ...     ...  ...
# 8121    CC1CC1CC(=O)Nc1cccc2c1n(C)c(=O)n2C1CCC(=O)NC1=O  Z0846a  Z1597a  NaN
# 8122  Cn1c(=O)n(C2CCC(=O)NC2=O)c2cccc(NC(=O)CCC3CC3)c21  Z0846a  Z1597a  NaN
# 8123  O=C(CCC1CC1)Nc1cc(Cl)cc2nc(-c3cc4ccccc4o3)[nH]c12  Z0846a  Z1597a  NaN
# 8124  O=C(CC1CCC1)Nc1cc(Cl)cc2nc(-c3cc4ccccc4o3)[nH]c12  Z0846a  Z1597a  NaN
# 8125  Cn1c(=O)n(C2CCC(=O)NC2=O)c2cccc(NC(=O)CC3CCC3)c21  Z0846a  Z1597a  NaN
#
#      hit4 hit5
# 0     NaN  NaN
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN
# ...   ...  ...
# 8121  NaN  NaN
# 8122  NaN  NaN
# 8123  NaN  NaN
# 8124  NaN  NaN
# 8125  NaN  NaN
#
# [8126 rows x 6 columns]

# %% [markdown]
# ## Define chemspace

# %%
scaffolds = animal.compounds(tag="openbind_xx01zvns2b_c1_scaffolds_chemok_bbok")
scaffolds
# Out:
# compounds tagged openbind_xx01zvns2b_c1_scaffolds_chemok_bbok: {C × 459}

# %%
elabs = scaffolds.elabs
elabs
# Out:
# {C × 13402}

# %%
posed_elabs = elabs.poses.compounds
posed_elabs
# Out:
# {C × 4731}

# %%
posed_elabs.add_tag("openbind_xx01zvns2b_c1_elabs")
# Out:
# Tagged {C × 4731} w/ "openbind_xx01zvns2b_c1_elabs"

# %%
posed_elabs.scaffolds.add_tag("openbind_xx01zvns2b_c1_elaborated_scaffolds")
# Out:
# Tagged {C × 64} w/ "openbind_xx01zvns2b_c1_elaborated_scaffolds"

# %%
chemspace = posed_elabs + posed_elabs.scaffolds
chemspace
# Out:
# {C × 4795}

# %%
full_recipe = hippo.Recipe.from_compounds(chemspace, use_routes=True, quoted_only=True, pick_first=True, pick_cheapest=False)
# Out:
# #compounds = 4795
# Output()
#  Warning  Multiple solutions for compound=C69166!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# Solving recipe combinations...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>

# %%
full_recipe
# Out:
# Recipe({Ingredient × 1396} --> {Ingredient × 4795} via {R × 4795})

# %%
full_recipe.price
# Out:
# €260576.00 EUR

# %%
full_recipe.write_json("cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs.json")
# Out:
#  DISK  Writing
# /opt/xchem-fragalysis-2/maxwin/openbind-hippo/xx01zvns2b/cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs
# .json...

# %%
full_recipe.write_CAR_csv("cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs_CAR.csv")
# Out:
# DEBUG: Querying database for routes
# DEBUG: Assembling route dictionary
# DEBUG: Checking availability
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
#  DISK  Writing
# /opt/xchem-fragalysis-2/maxwin/openbind-hippo/xx01zvns2b/cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs
# _CAR_1steps.csv...
#  DISK  Writing
# /opt/xchem-fragalysis-2/maxwin/openbind-hippo/xx01zvns2b/cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs
# _CAR.csv...
#      target-names  no-steps concentration-required-mM amount-required-uL  \
# 0         C142804         1                      None               None
# 1         C142805         1                      None               None
# 2         C142806         1                      None               None
# 3         C149211         1                      None               None
# 4         C142808         1                      None               None
# ...           ...       ...                       ...                ...
# 4790      C142787         1                      None               None
# 4791      C142788         1                      None               None
# 4792      C142791         1                      None               None
# 4793      C142793         1                      None               None
# 4794      C142794         1                      None               None
#
#      batch-tag                        reactant-1-1  \
# 0         None                  Nc1ccc2c(c1)CNC2=O
# 1         None  O=C(O)c1ccc2c(c1)C1(CCOCC1)C(=O)N2
# 2         None  O=C(O)c1ccc2c(c1)C1(CCOCC1)C(=O)N2
# 3         None             CC1CCCn2c(CC(=O)O)cnc21
# 4         None  O=C(O)c1ccc2c(c1)C1(CCOCC1)C(=O)N2
# ...        ...                                 ...
# 4790      None      Cc1ccc(C(=O)O)c2[nH]cc(C#N)c12
# 4791      None      Cc1ccc(C(=O)O)c2[nH]cc(C#N)c12
# 4792      None            Nc1ccc2c(c1)CN(CC(F)F)C2
# 4793      None         Nc1ccc2c(c1)CN(CC(F)(F)F)C2
# 4794      None      Cc1ccc(C(=O)O)c2[nH]cc(C#N)c12
#
#                             reactant-2-1  \
# 0     O=C(O)c1ccc2c(c1)C1(CCOCC1)C(=O)N2
# 1                   Nc1ccc2c(c1)C(=O)NC2
# 2                    CN1Cc2ccc(N)cc2C1=O
# 3                 Fc1cncc(Cl)c1CC1CCCCN1
# 4                    Nc1cc2c(cc1F)CNC2=O
# ...                                  ...
# 4790                CCN1Cc2ccc(N)cc2C1=O
# 4791               CN1Cc2cc(N)ccc2C1(C)C
# 4792      Cc1ccc(C(=O)O)c2[nH]cc(C#N)c12
# 4793      Cc1ccc(C(=O)O)c2[nH]cc(C#N)c12
# 4794           COCN1C(=O)c2ccc(N)cc2C1=O
#
#                               reaction-product-smiles-1 reaction-name-1  \
# 0     O=C(Nc1ccc2c(c1)CNC2=O)c1ccc2c(c1)C1(CCOCC1)C(...       Amidation
# 1     O=C(Nc1ccc2c(c1)C(=O)NC2)c1ccc2c(c1)C1(CCOCC1)...       Amidation
# 2     CN1Cc2ccc(NC(=O)c3ccc4c(c3)C3(CCOCC3)C(=O)N4)c...       Amidation
# 3          CC1CCCn2c(CC(=O)N3CCCCC3Cc3c(F)cncc3Cl)cnc21       Amidation
# 4     O=C(Nc1cc2c(cc1F)CNC2=O)c1ccc2c(c1)C1(CCOCC1)C...       Amidation
# ...                                                 ...             ...
# 4790  CCN1Cc2ccc(NC(=O)c3ccc(C)c4c(C#N)c[nH]c34)cc2C1=O       Amidation
# 4791  Cc1ccc(C(=O)Nc2ccc3c(c2)CN(C)C3(C)C)c2[nH]cc(C...       Amidation
# 4792  Cc1ccc(C(=O)Nc2ccc3c(c2)CN(CC(F)F)C3)c2[nH]cc(...       Amidation
# 4793  Cc1ccc(C(=O)Nc2ccc3c(c2)CN(CC(F)(F)F)C3)c2[nH]...       Amidation
# 4794  COCN1C(=O)c2ccc(NC(=O)c3ccc(C)c4c(C#N)c[nH]c34...       Amidation
#
#      reaction-recipe-1 reaction-groupby-column-1
# 0                 None                      None
# 1                 None                      None
# 2                 None                      None
# 3                 None                      None
# 4                 None                      None
# ...                ...                       ...
# 4790              None                      None
# 4791              None                      None
# 4792              None                      None
# 4793              None                      None
# 4794              None                      None
#
# [4795 rows x 11 columns]

# %%
full_recipe.write_reactant_csv("cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs_reactants.csv")
# Out:
# DEBUG: Querying database for routes
# DEBUG: Assembling route dictionary
# DEBUG: Checking availability
#  DISK  Writing cycle_01/syndirella/elabs/openbind_xx01zvns2b_c1_all_elabs_reactants.csv...
