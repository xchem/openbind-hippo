# %%
import pandas as pd

# %%
df = pd.read_pickle("cycle_01/syndirella/retrosynthesis/justretroquery_openbind_d68ev3c_c1_scaffolds_syndirella_input.pkl.gz")
df.head()
# Out:
#                               smiles template                   compound_set  \
# 0  OC(=NCCNc1cccc2nc(Cl)oc12)c1ccsc1   7gp3-a  openbind_d68ev3c_c1_scaffolds
# 1            NC(c1ccccc1)c1cccc(O)c1   7gp3-a  openbind_d68ev3c_c1_scaffolds
# 2    CCC1C(O)CC(F)C(F)C1C(N)c1ccccc1   7gp3-a  openbind_d68ev3c_c1_scaffolds
# 3    NC(c1ccccc1)C1CCCCC12CNC(O)CC2O   7gp3-a  openbind_d68ev3c_c1_scaffolds
# 4              NC(c1ccccc1)c1ccccc1I   7gp3-a  openbind_d68ev3c_c1_scaffolds
#
#      hit1    hit2 hit3 hit4 hit5  \
# 0  7gqr-a  7gp7-a  NaN  NaN  NaN
# 1  7gqb-a  7gp8-a  NaN  NaN  NaN
# 2  7gqb-a  7gpi-a  NaN  NaN  NaN
# 3  7gqb-a  7go7-a  NaN  NaN  NaN
# 4  7gqb-a  7go4-a  NaN  NaN  NaN
#
#                                               route0  \
# 0  [{'name': 'Buchwald-Hartwig_amination', 'react...
# 1  [{'name': 'Petasis-borono_Mannich_reaction', '...
# 2                                                NaN
# 3  [{'name': 'Amine_alkylation', 'reactantSmiles'...
# ...
