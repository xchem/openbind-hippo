# %%
# %load_ext autoreload
# %autoreload 2
import hippo
import mrich
from mrich import print
from pathlib import Path
from os import environ
import shutil
import molparse as mp

# %%
target_name = "D68EV3C"
target_dir = Path(environ["BULK"]) / "TARGETS" / target_name
cycle_name = "cycle_01"
cycle_dir = Path(cycle_name)
aligned_dir = target_dir / "aligned_files"

# %%
animal = hippo.HIPPO(target_name, "dev.sqlite")#, copy_from=target_dir / f"{target_name}.sqlite")
# Out:
#  Creating HIPPO animal
# name = D68EV3C
# db_path = dev.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = dev.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ dev.sqlite!
#  Success  Initialised animal HIPPO("D68EV3C")!

# %%
pose = animal.P10000

# print(pose.has_fingerprint)
# print(pose.interactions)

db = pose.calculate_interactions(force=True, debug=False)
db
# Out:
#  Warning  Skipped 14 protein features because the residue was mutated:!
#  Warning  CYS 93 -> TYR 93!

# %%
db.table_df("temp_interaction")
