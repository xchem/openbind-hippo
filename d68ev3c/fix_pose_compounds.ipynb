# %% [markdown]
# # OpenBind-HIPPO
#
# - **Target: A71EV2A**
# - **Cycle: 01**
#
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import hippo
import mrich
from mrich import print
from pathlib import Path
from os import environ
import shutil
import molparse as mp
import pandas as pd
import plotly.express as px
from hippo.tools import sanitise_smiles
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Config

# %%
target_name = "D68EV3C"
target_dir = Path(environ["BULK"]) / "TARGETS" / target_name
cycle_name = "cycle_01"
cycle_dir = Path(cycle_name)
aligned_dir = target_dir / "aligned_files"

# %% [markdown]
# ## Animal

# %%
animal.db.backup()
# Out:
#  DISK  Writing /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/D68EV3C/D68EV3C_1GE8MN3.sqlite...
# Output()
# DEBUG: Copied 10000 of 144594 pages...
# DEBUG: Copied 20000 of 144594 pages...
# DEBUG: Copied 30000 of 144594 pages...
# DEBUG: Copied 40000 of 144594 pages...
# DEBUG: Copied 50000 of 144594 pages...
# DEBUG: Copied 60000 of 144594 pages...
# DEBUG: Copied 70000 of 144594 pages...
# DEBUG: Copied 80000 of 144594 pages...
# DEBUG: Copied 90000 of 144594 pages...
# DEBUG: Copied 100000 of 144594 pages...
# DEBUG: Copied 120000 of 144594 pages...
# DEBUG: Copied 130000 of 144594 pages...
# DEBUG: Copied 140000 of 144594 pages...
# DEBUG: Copied 144594 of 144594 pages...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>

# %%
animal = hippo.HIPPO(target_name, target_dir / f"{target_name}.sqlite")
# Out:
#  Creating HIPPO animal
# name = D68EV3C
# db_path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/D68EV3C/D68EV3C.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/D68EV3C/D68EV3C.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/D68EV3C/D68EV3C.sqlite!
#  Success  Initialised animal HIPPO("D68EV3C")!

# %%
# %%time
animal.db.fix_incorrect_pose_compound_assignments()
