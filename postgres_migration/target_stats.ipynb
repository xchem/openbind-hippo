# %%
# %load_ext autoreload
# %autoreload 2
import hippo
from os import environ
from pathlib import Path
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
list((Path(environ["BULK"]) / "TARGETS").glob("*"))
# Out:
# [PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/FatA'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/FatA.zip'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/Flavi_NS5_RdRp.zip'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/Flavi_NS5_RdRp'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2AZ.zip'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/CpKRS.zip'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/CpKRS'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/ZIKA_NS3_helicase.zip'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/ZIKA_NS3_helicase'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2AZ_old'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A_old.zip'),
#  PosixPath('/opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2AZ'),
# ...

# %%
target = "A71EV2AZ"

# %%
animal = hippo.HIPPO(
    target, 
    Path(environ["BULK"]) / "TARGETS" / target / f"{target}.sqlite", 
    update_legacy=True,
)
# Out:
#  Creating HIPPO animal
# name = A71EV2AZ
# db_path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2AZ/A71EV2AZ.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2AZ/A71EV2AZ.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2AZ/A71EV2AZ.sqlite!
# DEBUG: Updating indexes
#  Success  Initialised animal HIPPO("A71EV2AZ")!

# %%
animal.db.execute("""
SELECT COUNT(1) FROM pose
WHERE pose_mol IS NULL
""").fetchone()
# Out:
# (0,)

# %%
animal.tags.summary()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ tag                         ┃ num_compounds ┃ num_poses ┃ num_posed_compounds ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ RefinementResolution        │ 0             │ 60        │ 53                  │
# │ [Other] upload_1 2025-09-11 │ 0             │ 60        │ 53                  │
# │ hits                        │ 53            │ 60        │ 53                  │
# └─────────────────────────────┴───────────────┴───────────┴─────────────────────┘

# %%
animal.poses
# Out:
# all poses: {P × 56610}

# %%
animal.compounds
# Out:
# all compounds: {C × 26970}

# %%
animal.db.execute("""
SELECT pose_id FROM pose
WHERE pose_mol IS NULL
""").fetchall()
# Out:
# [(110307,),
#  (110309,),
#  (284364,),
#  (284369,),
#  (284385,),
#  (297369,),
#  (323256,),
#  (323258,),
#  (323360,),
#  (323364,),
#  (323369,),
#  (323373,),
#  (323379,),
#  (323382,),
#  (323388,),
#  (323392,),
#  (323393,),
#  (323397,),
#  (323398,),
#  (323399,),
#  (323400,),
#  (323401,),
#  (323403,)]

# %%
animal.poses[110307].mol
# Out:
#  DISK  Reading /opt/xchem-fragalysis-2/maxwin/BulkDock/SCRATCH/353312/C22364-P76/C22364-P76.minimised.mol...
#  DISK  Reading /opt/xchem-fragalysis-2/maxwin/BulkDock/SCRATCH/353312/C22364-P76/C22364-P76.minimised.mol...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 animal.poses[110307].mol                                                                     │
# │   2                                                                                              │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# ...

# %%
animal.poses(tag="hits")[0].metadata
# Out:
# {'observation_longname': 'A71EV2AZ-x0229_A_301_v1', 'ConformerSites alias': '1a - A0503/A/245', 'CanonSites alias': '1 - A0503/A/245/1', 'CrystalformSites alias': 'F2a - A0229/A/301', 'Quatassemblies alias': 'A2 - monomer-precursor', 'Crystalforms alias': 'F2 - 1st_form', 'ConformerSites upload name': '1a - A71EV2AZ-x0503/A/245', 'CanonSites upload name': '1 - A71EV2AZ-x0503/A/245/1', 'CrystalformSites upload name': 'F2a - A71EV2AZ-x0229/A/301/1', 'Quatassemblies upload name': 'A2 - monomer-precursor', 'Crystalforms upload name': 'F2 - 1st_form', 'ConformerSites short tag': '1a - A0503/A/245', 'CanonSites short tag': '1 - A0503/A/245/1', 'CrystalformSites short tag': 'F2a - A0229/A/301', 'Quatassemblies short tag': 'A2 - monomer-precursor', 'Crystalforms short tag': 'F2 - 1st_form', 'Centroid res': 'A71EV2AZ-x0503/A/112/A_v1', 'Experiment code': 'A71EV2AZ-x0229', 'Pose': 'A0229a', 'exports': ['/opt/xchem-fragalysis-2/maxwin/2A_Precursor_FFF/syndirella/iter1_elabs_syndirella_inspirati
# ...

# %%
migration = json.load(open("A71EV2AZ_1QV27NC_migration.json", "rt"))

# %%
migration["pose_alias_map"]
# Out:
# {'A0229a': 'A71EV2AZ-x0229_A_301_v1',
#  'A0239a': 'A71EV2AZ-x0239_A_245_v1',
#  'A0423a': 'A71EV2AZ-x0423_A_301_v1',
#  'A0446a': 'A71EV2AZ-x0446_A_245_v1',
#  'A0503a': 'A71EV2AZ-x0503_A_245_v1',
#  'A0759a': 'A71EV2AZ-x0759_A_250_v1'}

# %%
animal = hippo.HIPPO("CHIKV", "../../CHIKV_FFF/hippo_prod/CHIKV_prod10c.sqlite", update_legacy=True)
# Out:
#  Creating HIPPO animal
# name = CHIKV
# db_path = ../../CHIKV_FFF/hippo_prod/CHIKV_prod10c.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = ../../CHIKV_FFF/hippo_prod/CHIKV_prod10c.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ ../../CHIKV_FFF/hippo_prod/CHIKV_prod10c.sqlite!
# DEBUG: Creating index_pose_inchikey
# DEBUG: Creating index_pose_smiles
# DEBUG: Creating index_pose_reference
# DEBUG: Creating index_pose_target
# DEBUG: Creating index_inspiration_original
# DEBUG: Creating index_inspiration_derivative
# DEBUG: Creating index_scaffold_superstructure
# DEBUG: Creating index_reaction_type
# DEBUG: Creating index_reaction_product
# DEBUG: Creating index_reactant_compound
# DEBUG: Creating index_tag_compound
# DEBUG: Creating index_tag_pose
# DEBUG: Creating index_quote_supplier
# DEBUG: Creating index_quote_catalogue
# DEBUG: Creating index_quote_entry
# DEBUG: Creating index_quote_compound
# ...

# %%
animal.tags.summary()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ tag                              ┃ num_compounds ┃ num_poses ┃ num_posed_compounds ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ DF                               │ 5             │ 0         │ 0                   │
# │ Enamine                          │ 251           │ 0         │ 0                   │
# │ JA                               │ 9             │ 0         │ 0                   │
# │ SeeSAR                           │ 14            │ 0         │ 0                   │
# │ Syndirella base                  │ 68            │ 32        │ 18                  │
# │ Syndirella elab                  │ 0             │ 15647     │ 11418               │
# │ Syndirella scaffold inspirations │ 0             │ 27        │ 22                  │
# │ [Other] ADPr                     │ 0             │ 4         │ 1                   │
# ...

# %%
# !export HIPPO_POSTGRES_USERNAME="

# %%
import mrich
from mrich import print

import hippo
from os import environ
from pathlib import Path

# connect to postgres

animal = hippo.HIPPO(
    "postgres", 
    dict(
        username=environ["HIPPO_POSTGRES_USERNAME"],
        password=environ["HIPPO_POSTGRES_PASSWORD"],
        port=5555,
        host="localhost",
        dbname="postgres",
        create_indexes=False,
    )
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:13                                                                                   │
# │                                                                                                  │
# │   10 animal = hippo.HIPPO(                                                                       │
# │   11 │   "postgres",                                                                             │
# │   12 │   dict(                                                                                   │
# │ ❱ 13 │   │   username=environ["HIPPO_POSTGRES_USERNAME"],                                        │
# │   14 │   │   password=environ["HIPPO_POSTGRES_PASSWORD"],                                        │
# │   15 │   │   port=5555,                                                                          │
# ...
