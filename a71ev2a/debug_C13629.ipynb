# %%
import hippo
import pandas as pd
import molparse as mp
from os import environ
from pathlib import Path

# %%
target_name = "A71EV2A"
target_dir = Path(environ["BULK"]) / "TARGETS" / target_name
cycle_name = "cycle_01"
cycle_dir = Path(cycle_name)
aligned_dir = target_dir / "aligned_files"

# %%
animal = hippo.HIPPO(target_name, target_dir / f"{target_name}.sqlite")
# Out:
#  Creating HIPPO animal
# name = A71EV2A
# db_path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A/A71EV2A.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A/A71EV2A.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A/A71EV2A.sqlite!
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
# SQLite Database was locked, retrying...
#  Success  Initialised animal HIPPO("A71EV2A")!

# %%
df = pd.read_pickle("cycle_01/syndirella/elabs/a71ev2a_c01_elabs_C1142/JWMDCIUJPJCIMA-UHFFFAOYSA-N/output/fstein_input.pkl.gz")
df
# Out:
#                                                   name  \
# 0    JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 1    JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 2    JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 3    JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 4    JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# ..                                                 ...
# 331  JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 332  JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 333  JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 334  JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
# 335  JWMDCIUJPJCIMA-UHFFFAOYSA-N-5f42d96aaf8d702f57...
#
#                                                 smiles  \
# 0    COc1ccc2c(c1)[C@H](NC(=O)OC(C)(C)C)CCN2C(=O)[C...
# 1    COc1ccc2c(c1)[C@@H](NC(=O)OC(C)(C)C)CCN2C(=O)[...
# 2    COc1ccc2c(c1)[C@H](NC(=O)OC(C)(C)C)CCN2C(=O)[C...
# 3    COc1ccc2c(c1)[C@@H](NC(=O)OC(C)(C)C)CCN2C(=O)[...
# ...

# %%
df = pd.read_pickle("cycle_01/syndirella/elabs/a71ev2a_c01_elabs_C79657/DURBHPZRTCPDPC-UHFFFAOYSA-N/DURBHPZRTCPDPC-UHFFFAOYSA-N_e2b15abb49e483e2f2b95c68a5f3e846_to_hippo.pkl.gz")
df.iloc[0]
# Out:
# scaffold_smiles                   CCc1cccc2sc(NC(=O)[C@H](O)c3c[nH]cn3)nc12
# 1_reaction                                                        Amidation
# 1_r1_smiles                                              Cn1cncc1C(O)C(=O)O
# 1_r2_smiles                                          CCc1cc(Br)cc2sc(N)nc12
# 1_r_previous_product                                                   None
# 1_product_smiles                CCc1cc(Br)cc2sc(NC(=O)[C@H](O)c3cncn3C)nc12
# 1_product_name            DURBHPZRTCPDPC-UHFFFAOYSA-N-e2b15abb49e483e2f2...
# 1_flag                                                                 None
# 1_single_reactant_elab                                                False
# 1_num_atom_diff                                                           2
# 1_stereoisomer                                                            A
# error
# ∆∆G                                                               26.495532
# ...

# %%
animal.C79657.smiles
# Out:
# 'CCc1cccc2sc(NC(=O)C(O)c3c[nH]cn3)nc12'
