# %% [markdown]
# # OpenBind-HIPPO
#
# - **Target: A71EV2A**
# - **Cycle: 01**
#
# ## Prep
#
# - [x] Downloaded A71EV2A with fragalysis_download.ipynb
# - [x] Bulkdock setup: `python -m bulkdock setup A71EV2A`
# - [x] Copy aligned files to here: `cp -rv $BULK/TARGETS/XX01ZVNS2B/aligned_files .`
#
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import hippo
import mrich
from mrich import print
from pathlib import Path
from os import environ
import shutil
import molparse as mp

# %% [markdown]
# # Config

# %%
target_name = "A71EV2A"
target_dir = Path(environ["BULK"]) / "TARGETS" / target_name
cycle_name = "cycle_01"
cycle_dir = Path(cycle_name)
aligned_dir = target_dir / "aligned_files"

# %% [markdown]
# ## Animal

# %%
animal = hippo.HIPPO(target_name, target_dir / f"{target_name}.sqlite")
# Out:
#  Creating HIPPO animal
# name = A71EV2A
# db_path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A/A71EV2A.sqlite
# DEBUG: hippo.Database.__init__()
# DEBUG: Database.path = /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A/A71EV2A.sqlite
# DEBUG: hippo.Database.connect()
# DEBUG: sqlite3.version='2.6.0'
#  Success  Database connected @ /opt/xchem-fragalysis-2/maxwin/BulkDock/TARGETS/A71EV2A/A71EV2A.sqlite!
#  Success  Initialised animal HIPPO("A71EV2A")!

# %%
animal.poses[-1].tags.add("test")

# %% [markdown]
# ## Merging
#
# Run merging algorithms on all poses tagged 'hits'

# %%
merge_input_poses = animal.poses(tag="hits")
merge_input_poses
# Out:
# poses tagged "hits": {P × 645}

# %% [markdown]
# ### Create inputs
#
# - CSV input for Knitwork
# - SDF of hits to merge for Knitwork and Fragmenstein
# - Protonated PDBs for Knitwork
# - Reference PDB for Fragmenstein

# %%
# output directories
knitwork_out_dir = cycle_dir / "knitwork"
knitwork_out_dir.mkdir(parents=True, exist_ok=True)
fragmenstein_out_dir = cycle_dir / "fragmenstein"
fragmenstein_out_dir.mkdir(parents=True, exist_ok=True)

# %%
# knitwork CSV
knitwork_out_dir = cycle_dir / "knitwork"
knitwork_out_dir.mkdir(parents=True, exist_ok=True)
merge_input_poses.to_knitwork(knitwork_out_dir / f"{cycle_name}_input.csv", path_root=knitwork_out_dir, aligned_files_dir="aligned_files")
# Out:
# out_path = /opt/xchem-fragalysis-2/maxwin/openbind-hippo/a71ev2a/cycle_01/knitwork/cycle_01_input.csv
# path_root = /opt/xchem-fragalysis-2/maxwin/openbind-hippo/a71ev2a/cycle_01/knitwork
# aligned_files_dir = aligned_files
#  DISK  Writing /opt/xchem-fragalysis-2/maxwin/openbind-hippo/a71ev2a/cycle_01/knitwork/cycle_01_input.csv...

# %%
# reference apo PDB for Fragmenstein
ref_pose = merge_input_poses[0]
mrich.var("ref_pose", ref_pose)
shutil.copy(ref_pose.apo_path, fragmenstein_out_dir)
# Out:
# ref_pose = C1->P1: "A5666a"
# 'cycle_01/fragmenstein/A5666a_apo-desolv.pdb'

# %%
# SDF of hits
out_dir = cycle_dir
out_dir.mkdir(parents=True, exist_ok=True)
merge_input_poses.write_sdf(cycle_dir / f"{cycle_name}_hits.sdf")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>
#  DISK  Writing cycle_01/cycle_01_hits.sdf...

# %%
#protonated PDBs
for pose in mrich.track(merge_input_poses):
    path = pose.apo_path
    sys = mp.parse(path,verbosity=False)
    sys.add_hydrogens(pH=7)
    subdir = Path("aligned_files") / pose.name
    subdir.mkdir(exist_ok=True, parents=True)
    sys.write(subdir / str(path.name).replace('_apo-desolv.pdb', '_apo-desolv-Hs.pdb'), verbosity=1)
# Out:
# Output()
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5666a/A5666a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 278 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A4298a/A4298a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A4918a/A4918a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5151a/A5151a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0450a/A0450a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0451a/A0451a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0469a/A0469a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0473a/A0473a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0486a/A0486a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 278 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0487a/A0487a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0488a/A0488a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0497a/A0497a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0501a/A0501a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0501b/A0501b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 278 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0514a/A0514a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 278 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0514b/A0514b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0515a/A0515a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0515b/A0515b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0517a/A0517a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0525a/A0525a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0526a/A0526a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0528a/A0528a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0528b/A0528b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0540a/A0540a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0541a/A0541a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0554b/A0554b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0554a/A0554a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0556a/A0556a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0566a/A0566a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0571a/A0571a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0586a/A0586a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0269a/A0269a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0278a/A0278a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0278b/A0278b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0305a/A0305a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0309a/A0309a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0310a/A0310a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0608a/A0608a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0691a/A0691a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0152a/A0152a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0152b/A0152b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0188a/A0188a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0194a/A0194a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0202b/A0202b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0202a/A0202a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0207a/A0207a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0228a/A0228a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0229a/A0229a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0229b/A0229b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0237a/A0237a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0239a/A0239a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0332a/A0332a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0333a/A0333a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0341a/A0341a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0351c/A0351c_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0351a/A0351a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0351b/A0351b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0354a/A0354a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0359a/A0359a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0365a/A0365a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0375a/A0375a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0375b/A0375b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0375c/A0375c_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0379a/A0379a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 278 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0387a/A0387a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0395a/A0395a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0395b/A0395b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0396a/A0396a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0412a/A0412a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0416a/A0416a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0428a/A0428a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0432a/A0432a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 278 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0437a/A0437a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0443a/A0443a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0446a/A0446a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0717a/A0717a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0719a/A0719a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0719b/A0719b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0732a/A0732a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0739a/A0739a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0812a/A0812a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0831a/A0831a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0836a/A0836a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0836b/A0836b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0853a/A0853a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0863a/A0863a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0875a/A0875a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0875b/A0875b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0884a/A0884a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0900a/A0900a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0911a/A0911a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A0922a/A0922a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A0926a/A0926a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1019a/A1019a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1068a/A1068a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1068b/A1068b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1068c/A1068c_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1080a/A1080a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1081a/A1081a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1081b/A1081b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1084a/A1084a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1105a/A1105a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A1105b/A1105b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/
_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5289b/A5289b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 139 (GLU) of chain 0>: ['OXT'], <Residue 279 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5317a/A5317a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 276 (ASP) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5339a/A5339a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT'], <Residue 276 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5339b/A5339b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5359a/A5359a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5359b/A5359b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5366a/A5366a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5366b/A5366b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5383a/A5383a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5388a/A5388a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5389a/A5389a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5393a/A5393a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 276 (ASP) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5394a/A5394a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT'], <Residue 276 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5394b/A5394b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5402a/A5402a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5424a/A5424a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5424b/A5424b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5425a/A5425a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5425b/A5425b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5427a/A5427a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5449a/A5449a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5449b/A5449b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5460a/A5460a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5466a/A5466a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5475a/A5475a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5475b/A5475b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5488a/A5488a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5509a/A5509a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5512b/A5512b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5525a/A5525a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5525b/A5525b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5539a/A5539a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5539b/A5539b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5544a/A5544a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 276 (ASP) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5584a/A5584a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT'], <Residue 276 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5584b/A5584b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5594a/A5594a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5594b/A5594b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 276 (ASP) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5598a/A5598a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 137 (ASP) of chain 0>: ['OXT'], <Residue 276 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5598b/A5598b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5599a/A5599a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5599b/A5599b_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT']}
#  DISK  Writing aligned_files/A5604a/A5604a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5608a/A5608a_apo-desolv-Hs.pdb...
# fixer.missingTerminals={<Residue 138 (GLU) of chain 0>: ['OXT'], <Residue 277 (GLU) of chain 1>: ['OXT']}
#  DISK  Writing aligned_files/A5608b/A5608b_apo-desolv-Hs.pdb...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace;margin:0px"></pre>

# %% [markdown]
# ### Run Fragmenstein
#
# ```
# cd cycle_01/fragmenstein
# sbatch --job-name "a71ev2a_fragmenstein" --mem 16000 $HOME2/slurm/run_bash_with_conda.sh ../../../run_fragmenstein.sh
# ```
#
# ### Run Knitwork
#
# - [ ] Clone repo on graph-sw-2
# - [ ] `cd TARGET/cycle_01/knitwork`
# - [ ] Run the "fragment" step of FragmentKnitwork: `../../../scripts/run_knitwork_fragment.sh`
# - [ ] Run the pure "knitting" step of FragmentKnitwork:`../../../scripts/run_knitwork_pure.sh`
# - [ ] Run the impure "knitting" step of FragmentKnitwork: `../../../scripts/run_knitwork_impure.sh`
# - [ ] Create bulkdock inputs: `knitwork_to_bulkdock.py`

# %% [markdown]
# # Fix smiles and aliases

# %%
# Fix smiles<>alias

sql = """SELECT pose_id
FROM pose
WHERE pose_smiles GLOB 'C[0-9]*-P[0-9]*';"""

ids = [i for i, in animal.db.execute(sql)]

poses = animal.poses[ids]

print(poses)

if poses:
    
    records = animal.db.select_where(table="pose", query="pose_id", key=f"pose_id IN {poses.str_ids}", multiple=True)
    
    sql = """
    UPDATE pose
    SET pose_alias = NULL, pose_smiles = mol_to_smiles(mol_from_binary_mol(pose_mol))
    WHERE pose_id = ?1
    """
    
    animal.db.executemany(sql, records)
# Out:
# {P × 90863}

# %%
animal.db.commit()
